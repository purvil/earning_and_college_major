# %% [markdown]
# * We will explore job outcome of students who graduated between year 2010 and 2012.
# * Each row represents different majors in college.
# * Data set has columns,
#     - `Rank` - Rank by median earnings (the dataset is ordered by this column).
#     - `Major_code` - Major code.
#     - `Major` - Major description.
#     - `Major_category` - Category of major.
#     - `Total` - Total number of people with major.
#     - `Sample_size` - Sample size (unweighted) of full-time.
#     - `Men` - Male graduates.
#     - `Women` - Female graduates.
#     - `ShareWomen` - Women as share of total.
#     - `Employed` - Number employed.
#     - `Median` - Median salary of full-time, year-round workers.
#     - `Low_wage_jobs` - Number in low-wage service jobs.
#     - `Full_time` - Number employed 35 hours or more.
#     - `Part_time` - Number employed less than 35 hours.

# %% [markdown]
# ### Import and explore data

# %%
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
recent_grads = pd.read_csv('data/recent-grads.csv')

# %%
recent_grads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 21 columns):
# Rank                    173 non-null int64
# Major_code              173 non-null int64
# Major                   173 non-null object
# Total                   172 non-null float64
# Men                     172 non-null float64
# Women                   172 non-null float64
# Major_category          173 non-null object
# ShareWomen              172 non-null float64
# Sample_size             173 non-null int64
# Employed                173 non-null int64
# Full_time               173 non-null int64
# Part_time               173 non-null int64
# Full_time_year_round    173 non-null int64
# Unemployed              173 non-null int64
# Unemployment_rate       173 non-null float64
# Median                  173 non-null int64
# P25th                   173 non-null int64
# P75th                   173 non-null int64
# College_jobs            173 non-null int64
# ...

# %%
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %% [markdown]
# ### Handle missing values
# * As matplotlib requires all columns to have same length, We need to clean up records with missing values

# %%
recent_grads.loc[recent_grads.isna().any(axis = 1), :]
# Out:
#     Rank  Major_code         Major  Total  Men  Women  \
# 21    22        1104  FOOD SCIENCE    NaN  NaN    NaN
#
#                      Major_category  ShareWomen  Sample_size  Employed  \
# 21  Agriculture & Natural Resources         NaN           36      3149
#
#         ...        Part_time  Full_time_year_round  Unemployed  \
# 21      ...             1121                  1735         338
#
#     Unemployment_rate  Median  P25th  P75th  College_jobs  Non_college_jobs  \
# 21           0.096931   53000  32000  70000          1183              1274
#
#     Low_wage_jobs
# 21            485
#
# [1 rows x 21 columns]

# %%
recent_grads.shape
# Out:
# (173, 21)

# %% [markdown]
# * Lets drop the row for major Food Science.

# %%
recent_grads = recent_grads.dropna()

# %%
recent_grads.shape
# Out:
# (172, 21)

# %% [markdown]
# ### Explore relationship between columns
#
# #### Explore sample of full time students and median salary

# %%
recent_grads.plot(kind='scatter', x='Sample_size', y='Median')

# %% [markdown]
# #### Sample size and unemployment rate

# %%
recent_grads.plot(kind='scatter', x='Sample_size', y='Unemployment_rate')

# %%
recent_grads.plot.hexbin(x = 'Sample_size', y='Unemployment_rate',gridsize=25)

# %% [markdown]
# #### Employed as full time and Median salary

# %%
recent_grads.plot(kind='scatter', x='Full_time', y='Median')

# %% [markdown]
# * Looks slightly downward trend. More full time employed less median salary.

# %% [markdown]
# #### Sharewomen and unemployment rate

# %%
recent_grads.plot(kind='scatter', x='ShareWomen', y='Unemployment_rate')

# %% [markdown]
# #### Men and Median salary

# %%
recent_grads.plot(kind='scatter', x='Men', y='Median')

# %% [markdown]
# #### Women and Median salary

# %%
recent_grads.plot(kind='scatter', x='Women', y='Median')

# %% [markdown]
# ### Explore distribution of values

# %%
recent_grads.Median.hist(bins=20)

# %%
recent_grads.Sample_size.hist()

# %%
recent_grads.Employed.hist()

# %%
recent_grads.Full_time.hist()

# %%
recent_grads.ShareWomen.hist()

# %%
recent_grads.Unemployment_rate.hist()

# %%
recent_grads.Men.hist()

# %%
recent_grads.Women.hist()

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002B0C55D54E0>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size','Median','Unemployment_rate']], 
               figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002B0C584B7F0>,
# ...
#       dtype=object)

# %%
(recent_grads.sort_values('ShareWomen', ascending=False)[:10]
 .plot.barh(x = 'Major',y='ShareWomen'))

# %%
recent_grads.sort_values('ShareWomen')[:10].plot.barh(x = 'Major', 
                                                      y='ShareWomen')

# %%
(recent_grads.sort_values('Unemployment_rate', ascending=False)[:10].
    plot.barh(x='Major', y='Unemployment_rate'))

# %%
(recent_grads.sort_values('Unemployment_rate')[:10].
    plot.barh(x='Major', y='Unemployment_rate'))

# %%
recent_grads.sort_values('Total',ascending=False)[:10].plot.barh(x = 'Major', y = ['Men', 'Women'])

# %%
plt.boxplot(recent_grads['Median'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2b0c8b15908>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2b0c8f8c668>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2b0c8b15240>],
#  'medians': [<matplotlib.lines.Line2D at 0x2b0c8b1f2b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2b0c8b1f898>],
#  'means': []}
